# %%
import pandas as pd
import numpy as np

data = pd.read_csv("truspilot_data.csv", delimiter=";;", engine="python")
data
# Out:
#                 time     company                     name  rating  \
# 0     ll y a 7 jours  google.com               guiademsan     3.0
# 1       14 avr. 2025  google.com        Kemo Badako Conde     1.0
# 2       26 mars 2025  google.com                 ElTitouk     1.0
# 3       19 mars 2025  google.com  brigitte Espes-agramunt     5.0
# 4       19 mars 2025  google.com                        C     1.0
# ...              ...         ...                      ...     ...
# 1126   16 janv. 2023    dior.com                      div     1.0
# 1127   12 janv. 2023    dior.com           Sandra Martini     1.0
# 1128   11 janv. 2023    dior.com                  BLAISOU     1.0
# 1129    6 janv. 2023    dior.com                     jean     1.0
# 1130    2 janv. 2023    dior.com            MICHEL BONNOT     1.0
#
#                                                 comment
# 0     J'utilise fréquemment ce site et j'apprécie bi...
# 1                  Bonsoir mon frère je vais bien merci
# ...
